# %%
import pandas as pd
import numpy as np

# Load the data (have to change the name for each sport
acc_path = 'walking/Accelerometer.csv'
grav_path = 'walking/Gravity.csv'
gyro_path = 'walking/Gyroscope.csv'
hr_path = 'walking/HeartRate.csv'
wrist_path = 'walking/WristMotion.csv'
acc_phone_data = pd.read_csv(acc_path)
grav_data = pd.read_csv(grav_path)
gyro_phone_data = pd.read_csv(gyro_path)
wrist_data = pd.read_csv(wrist_path)
hr_data = pd.read_csv(hr_path)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# /var/folders/70/l7qk07cx5wjcwkjjzw0pwjc00000gn/T/ipykernel_35257/3961167551.py in <module>
#      12 gyro_phone_data = pd.read_csv(gyro_path)
#      13 wrist_data = pd.read_csv(wrist_path)
# ---> 14 hr_data = pd.read_csv(hr_path)
#      15
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1232
#    1233         try:
# -> 1234             return mapping[engine](f, **self.options)
#    1235         except Exception:
#    1236             if self.handles is not None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      73
#      74         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75         self._reader = parsers.TextReader(src, **kwds)
#      76
#      77         self.unnamed_cols = self._reader.unnamed_cols
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %% [markdown]
# Data Merging

# %%
wrist_data
# Out:
#                        time  seconds_elapsed  rotationRateX  rotationRateY  \
# 0       1718311090903299300         2.301299       0.040385       0.049638
# 1       1718311090913261000         2.311261       0.032671       0.034696
# 2       1718311090923224300         2.321224       0.008491       0.015564
# 3       1718311090933186300         2.331186      -0.014403       0.049653
# 4       1718311090943148300         2.341148      -0.105676       0.170725
# ...                     ...              ...            ...            ...
# 121987  1718312306197949000      1217.595949      -0.230445      -0.064104
# 121988  1718312306207912000      1217.605912      -0.297640      -0.068602
# 121989  1718312306217874000      1217.615874      -0.339981      -0.037667
# 121990  1718312306227837000      1217.625837      -0.398897      -0.007283
# 121991  1718312306237799000      1217.635799      -0.485303       0.043107
#
#         rotationRateZ  gravityX  gravityY  gravityZ  accelerationX  \
# 0           -0.009559  0.405645 -0.139336 -0.903348       0.037027
# 1            0.013400  0.406020 -0.139673 -0.903127       0.035783
# 2            0.023396  0.406241 -0.139929 -0.902989       0.028131
# 3            0.040736  0.406436 -0.140022 -0.902886       0.032514
# 4            0.173346  0.408485 -0.139920 -0.901977       0.027458
# ...               ...       ...       ...       ...            ...
# 121987       0.013868 -0.095385  0.885194 -0.455338      -0.004240
# 121988      -0.004050 -0.095701  0.886203 -0.453305      -0.002321
# 121989      -0.007861 -0.096051  0.887323 -0.451034       0.005887
# 121990      -0.009314 -0.096221  0.888652 -0.448375       0.014113
# 121991      -0.017672 -0.096259  0.890353 -0.444979       0.008200
#
#         accelerationY  accelerationZ  quaternionW  quaternionX  quaternionY  \
# 0            0.009804      -0.012622     0.975538     0.071415     0.207909
# 1            0.005060      -0.005183     0.975481     0.071595     0.208112
# 2           -0.003519       0.001438     0.975446     0.071712     0.208238
# 3           -0.011345       0.002999     0.975420     0.071726     0.208356
# 4           -0.017612       0.012161     0.975186     0.071542     0.209507
# ...               ...            ...          ...          ...          ...
# 121987      -0.011827      -0.018081     0.838457    -0.499691    -0.150467
# 121988      -0.017490      -0.041614     0.837852    -0.500570    -0.150923
# 121989      -0.024347      -0.053406     0.837197    -0.501569    -0.151367
# 121990      -0.036937      -0.057210     0.836443    -0.502791    -0.151704
# 121991      -0.054049      -0.050306     0.835503    -0.504401    -0.151954
#
#          quaternionZ
# 0      -4.884339e-18
# 1      -1.498378e-05
# 2       6.458120e-05
# 3       2.293681e-04
# 4       9.192861e-04
# ...              ...
# 121987  1.570325e-01
# 121988  1.570218e-01
# 121989  1.569042e-01
# 121990  1.566884e-01
# 121991  1.562823e-01
#
# [121992 rows x 15 columns]

# %%
acc_phone_data
# Out:
#                       time  seconds_elapsed         z         y         x
# 0      1718292420959481900         0.019482  0.033051  0.016458 -0.002570
# 1      1718292421009252900         0.069253 -0.026291  0.039965 -0.031247
# 2      1718292421059025000         0.119025  0.345929 -0.000943 -0.015137
# 3      1718292421108796000         0.168796  0.051314 -0.007389 -0.034977
# 4      1718292421158567200         0.218567 -0.125445  0.192159  0.062626
# ...                    ...              ...       ...       ...       ...
# 36141  1718294219701012700      1798.761013  0.030543  0.022076  0.127806
# 36142  1718294219750783700      1798.810784 -0.244426  0.083532 -0.134145
# 36143  1718294219800554800      1798.860555  0.281002  0.038497 -0.162475
# 36144  1718294219850326800      1798.910327  0.436477 -0.212799 -0.276245
# 36145  1718294219900097300      1798.960097 -0.045699  0.277418  0.030452
#
# [36146 rows x 5 columns]

# %%
hr_data
# Out:
#                     time  seconds_elapsed    bpm
# 0    1718292425773628200         4.833628   99.0
# 1    1718292426773628200         5.833628   99.0
# 2    1718292431773628200        10.833628  102.0
# 3    1718292436773628200        15.833628  105.0
# 4    1718292445773628200        24.833628  102.0
# ..                   ...              ...    ...
# 346  1718294192768804000      1771.828804  139.0
# 347  1718294198768804000      1777.828804  138.0
# 348  1718294203768804000      1782.828804  140.0
# 349  1718294207768804000      1786.828804  140.0
# 350  1718294214768804000      1793.828804  137.0
#
# [351 rows x 3 columns]

# %%
def remove_last_digits(number):
    return number // 10000000

#I remove the last digit from the time column, as they were to detailed and impossible to have tow equal
wrist_data['time']=wrist_data['time'].apply(remove_last_digits)
acc_phone_data['time']=acc_phone_data['time'].apply(remove_last_digits)
gyro_phone_data['time']=gyro_phone_data['time'].apply(remove_last_digits)
hr_data['time']=hr_data['time'].apply(remove_last_digits)

#As result of removal, I delete all duplicates, keeping the first ones
wrist_data = wrist_data.drop_duplicates(subset='time', keep='first')
acc_phone_data = acc_phone_data.drop_duplicates(subset='time', keep='first')
gyro_phone_data = gyro_phone_data.drop_duplicates(subset='time', keep='first')
hr_data= hr_data.drop_duplicates(subset='time', keep='first')
wrist_data
# Out:
#                 time  seconds_elapsed  rotationRateX  rotationRateY  \
# 0       171829242110         0.160953      -0.055229       0.017896
# 1       171829242111         0.170916      -0.041418       0.010941
# 2       171829242112         0.180879      -0.021295       0.006904
# 3       171829242113         0.190842       0.000407       0.005939
# 4       171829242114         0.200805       0.014838       0.012198
# ...              ...              ...            ...            ...
# 180535  171829421944      1798.500627      -0.013685       0.005364
# 180536  171829421945      1798.510588      -0.009635       0.016024
# 180537  171829421946      1798.520549      -0.001993       0.027773
# 180538  171829421947      1798.530510       0.008116       0.032674
# 180539  171829421948      1798.540471       0.005440       0.044996
#
#         rotationRateZ  gravityX  gravityY  gravityZ  accelerationX  \
# 0            0.005337  0.198594 -0.023389 -0.979803      -0.000596
# 1            0.009057  0.198711 -0.022994 -0.979788       0.000401
# 2           -0.001709  0.198840 -0.022483 -0.979774       0.004514
# 3           -0.008424  0.198932 -0.022148 -0.979763       0.006955
# 4           -0.010322  0.198985 -0.022178 -0.979752       0.004491
# ...               ...       ...       ...       ...            ...
# 180535       0.021725  0.144628  0.875216 -0.461606      -0.001241
# 180536       0.015298  0.144889  0.875120 -0.461706      -0.001319
# 180537       0.011007  0.145122  0.875080 -0.461708      -0.000636
# 180538       0.008313  0.145353  0.875011 -0.461767      -0.007948
# 180539       0.012418  0.145679  0.874934 -0.461809      -0.005542
#
#         accelerationY  accelerationZ  quaternionW  quaternionX  quaternionY  \
# 0           -0.020434       0.017858     0.994938     0.011754     0.099802
# 1           -0.009049       0.007956     0.994934     0.011549     0.099862
# 2            0.009635      -0.005501     0.994931     0.011289     0.099928
# 3            0.015984      -0.014408     0.994928     0.011125     0.099974
# 4            0.008262      -0.014313     0.994925     0.011145     0.100000
# ...               ...            ...          ...          ...          ...
# 180535      -0.001543       0.010816     0.609444    -0.305618     0.419279
# 180536       0.005877       0.011480     0.609519    -0.305498     0.419307
# 180537       0.010799       0.013511     0.609532    -0.305394     0.419381
# 180538       0.014164       0.013875     0.609519    -0.305247     0.419453
# 180539       0.016728       0.008074     0.609493    -0.305053     0.419569
#
#          quaternionZ
# 0       5.088456e-18
# 1       6.614573e-05
# 2       9.021612e-05
# 3       5.778709e-05
# 4       7.491470e-06
# ...              ...
# 180535 -5.994839e-01
# 180536 -5.994497e-01
# 180537 -5.994376e-01
# 180538 -5.994753e-01
# 180539 -5.995186e-01
#
# [179838 rows x 15 columns]

# %%
hr_data
# Out:
#              time  seconds_elapsed    bpm
# 0    171829242577         4.833628   99.0
# 1    171829242677         5.833628   99.0
# 2    171829243177        10.833628  102.0
# 3    171829243677        15.833628  105.0
# 4    171829244577        24.833628  102.0
# ..            ...              ...    ...
# 346  171829419276      1771.828804  139.0
# 347  171829419876      1777.828804  138.0
# 348  171829420376      1782.828804  140.0
# 349  171829420776      1786.828804  140.0
# 350  171829421476      1793.828804  137.0
#
# [351 rows x 3 columns]

# %%
# Merge the phone datasets on the timestamp column
merged_phone = pd.merge(gyro_phone_data,acc_phone_data,how='inner', on='time',suffixes=('_gyro', '_acc'))
# Merge the watch and the phone datasets on the timestamp column
merged_data_1 = pd.merge(wrist_data,merged_phone,how='inner', on='time', suffixes=('_watch', '_phone'))

merged_data = pd.merge_asof(merged_data_1,hr_data,direction='nearest', on='time',suffixes=('','_hr'))

# Print the result ( we have more or less the same freq as the phone (20Hz)
merged_data
# Out:
#                time  seconds_elapsed  rotationRateX  rotationRateY  \
# 0      171829242110         0.160953      -0.055229       0.017896
# 1      171829242115         0.210769       0.008456       0.013454
# 2      171829242120         0.260583      -0.002253      -0.003599
# 3      171829242125         0.310397      -0.021693      -0.002480
# 4      171829242130         0.360212       0.037385       0.009602
# ...             ...              ...            ...            ...
# 36129  171829421925      1798.311365      -0.001288       0.037205
# 36130  171829421930      1798.361170       0.019267       0.022002
# 36131  171829421935      1798.410976      -0.013120      -0.002966
# 36132  171829421940      1798.460782      -0.006443      -0.016840
# 36133  171829421945      1798.510588      -0.009635       0.016024
#
#        rotationRateZ  gravityX  gravityY  gravityZ  accelerationX  \
# 0           0.005337  0.198594 -0.023389 -0.979803      -0.000596
# 1          -0.006067  0.199160 -0.022376 -0.979711      -0.001407
# 2          -0.000467  0.199826 -0.022304 -0.979577       0.001361
# 3           0.007295  0.199356 -0.022358 -0.979672      -0.006928
# 4          -0.008600  0.199618 -0.021907 -0.979629       0.007413
# ...              ...       ...       ...       ...            ...
# 36129      -0.000034  0.141162  0.876746 -0.459771       0.007093
# 36130      -0.003056  0.141741  0.876611 -0.459851       0.006116
# 36131       0.017809  0.142109  0.876399 -0.460140       0.010891
# 36132       0.028178  0.143334  0.875818 -0.460867       0.005912
# 36133       0.015298  0.144889  0.875120 -0.461706      -0.001319
#
#        accelerationY  ...  seconds_elapsed_gyro    z_gyro    y_gyro    x_gyro  \
# 0          -0.020434  ...              0.168796 -0.018684  0.053260 -0.065799
# 1           0.002448  ...              0.218567  0.011560  0.007464  0.018411
# 2           0.005962  ...              0.268338  0.023064  0.007878  0.034555
# 3          -0.015224  ...              0.318110 -0.022753 -0.072434  0.196878
# 4           0.019557  ...              0.367881  0.017803  0.035977 -0.126318
# ...              ...  ...                   ...       ...       ...       ...
# 36129       0.002435  ...           1798.313075 -0.005900  0.034623  0.000286
# 36130      -0.011895  ...           1798.362846 -0.025944  0.040966 -0.053644
# 36131      -0.009548  ...           1798.412616  0.008401 -0.000977  0.024358
# 36132       0.000861  ...           1798.462387  0.013277 -0.002801 -0.038290
# 36133       0.005877  ...           1798.512158  0.013655  0.018239 -0.064116
#
#        seconds_elapsed_acc     z_acc     y_acc     x_acc  seconds_elapsed_hr  \
# 0                 0.168796  0.051314 -0.007389 -0.034977            4.833628
# 1                 0.218567 -0.125445  0.192159  0.062626            4.833628
# 2                 0.268338 -0.102298 -0.081654 -0.029546            4.833628
# 3                 0.318110  0.039218 -0.032067 -0.114867            4.833628
# 4                 0.367881  0.452056  0.027856  0.080952            4.833628
# ...                    ...       ...       ...       ...                 ...
# 36129          1798.313075 -0.063131  0.121282  0.227220         1793.828804
# 36130          1798.362846  0.159545 -0.055427 -0.025500         1793.828804
# 36131          1798.412616  0.011866  0.086600  0.146586         1793.828804
# 36132          1798.462387  0.413557 -0.093723 -0.062594         1793.828804
# 36133          1798.512158  0.028775  0.028965 -0.067718         1793.828804
#
#          bpm
# 0       99.0
# 1       99.0
# 2       99.0
# 3       99.0
# 4       99.0
# ...      ...
# 36129  137.0
# 36130  137.0
# 36131  137.0
# 36132  137.0
# 36133  137.0
#
# [36134 rows x 25 columns]

# %%
merged_data.columns
# Out:
# Index(['time', 'seconds_elapsed', 'rotationRateX', 'rotationRateY',
#        'rotationRateZ', 'gravityX', 'gravityY', 'gravityZ', 'accelerationX',
#        'accelerationY', 'accelerationZ', 'quaternionW', 'quaternionX',
#        'quaternionY', 'quaternionZ', 'seconds_elapsed_gyro', 'z_gyro',
#        'y_gyro', 'x_gyro', 'seconds_elapsed_acc', 'z_acc', 'y_acc', 'x_acc',
#        'seconds_elapsed_hr', 'bpm'],
#       dtype='object')

# %%
merged_data=merged_data.drop(columns=['seconds_elapsed','seconds_elapsed_gyro','seconds_elapsed_acc','seconds_elapsed_hr'])

# %% [markdown]
# Data Cleaning

# %%
import math
import scipy 
def mark_outliers_chauvenet(dataset, C=2):
    """Finds outliers in the specified column of datatable and adds a binary column with
    the same name extended with '_outlier' that expresses the result per data point.

    Taken from: https://github.com/mhoogen/ML4QS/blob/master/Python3Code/Chapter3/OutlierDetection.py

    Args:
        dataset (pd.DataFrame): The dataset
        col (string): The column you want apply outlier detection to
        C (int, optional): Degree of certainty for the identification of outliers given the assumption
                           of a normal distribution, typicaly between 1 - 10. Defaults to 2.

    Returns:
        pd.DataFrame: The original dataframe with an extra boolean column
        indicating whether the value is an outlier or not.
    """

    
    dataset = dataset.copy()
        # Compute the mean and standard deviation.
    for col in dataset.columns:
        
        mean = dataset[col].mean()
        std = dataset[col].std()
        N = len(dataset.index)
        criterion = 1.0 / (C * N)
    
        # Consider the deviation for the data points.
        deviation = abs(dataset[col] - mean) / std
    
        
        # Express the upper and lower bounds.
        low = -deviation / np.sqrt(C)
        high = deviation / np.sqrt(C)
        
        # Determine the probability of observing the points
        prob = 1.0 - 0.5 * (scipy.special.erf(high) - scipy.special.erf(low))
        
        # Create a mask for non-outliers
        mask = prob >= criterion
        
        # Apply the mask to remove the outliers for this column
        dataset = dataset[mask]
        dataset = dataset.dropna()
    return dataset

filtered_df=mark_outliers_chauvenet(merged_data, C=2)
filtered_df
# Out:
#                time  rotationRateX  rotationRateY  rotationRateZ  gravityX  \
# 265    171829243429      -0.246384      -0.081519       0.110493  0.317334
# 266    171829243434      -0.138480      -0.123311       0.156557  0.319853
# 267    171829243439      -0.078834      -0.117711       0.288981  0.324156
# 268    171829243444       0.135324      -0.119591       0.278078  0.331465
# 269    171829243449       0.171445      -0.084271       0.341000  0.341875
# ...             ...            ...            ...            ...       ...
# 36129  171829421925      -0.001288       0.037205      -0.000034  0.141162
# 36130  171829421930       0.019267       0.022002      -0.003056  0.141741
# 36131  171829421935      -0.013120      -0.002966       0.017809  0.142109
# 36132  171829421940      -0.006443      -0.016840       0.028178  0.143334
# 36133  171829421945      -0.009635       0.016024       0.015298  0.144889
#
#        gravityY  gravityZ  accelerationX  accelerationY  accelerationZ  ...  \
# 265    0.813489 -0.487376      -0.042294      -0.031018       0.024852  ...
# 266    0.817145 -0.479550      -0.028440       0.049691      -0.053638  ...
# 267    0.815928 -0.478733      -0.063689      -0.070124      -0.042721  ...
# 268    0.810568 -0.482816      -0.048292       0.014734      -0.036853  ...
# 269    0.801126 -0.491243       0.001311       0.071738      -0.023100  ...
# ...         ...       ...            ...            ...            ...  ...
# 36129  0.876746 -0.459771       0.007093       0.002435      -0.010261  ...
# 36130  0.876611 -0.459851       0.006116      -0.011895      -0.015354  ...
# 36131  0.876399 -0.460140       0.010891      -0.009548      -0.022862  ...
# 36132  0.875818 -0.460867       0.005912       0.000861      -0.006296  ...
# 36133  0.875120 -0.461706      -0.001319       0.005877       0.011480  ...
#
#        quaternionX  quaternionY  quaternionZ    z_gyro    y_gyro    x_gyro  \
# 265      -0.254078    -0.437900     0.852192 -0.138021 -0.582045 -0.219524
# 266      -0.254049    -0.442362     0.850672 -0.203224 -0.220469 -0.020842
# 267      -0.253063    -0.443388     0.851395 -0.172186 -0.185771  0.024884
# 268      -0.253136    -0.441038     0.853461 -0.156555 -0.071315  0.144891
# 269      -0.254364    -0.435520     0.856728 -0.313300  0.043542  0.165136
# ...            ...          ...          ...       ...       ...       ...
# 36129    -0.307346     0.419110    -0.599871 -0.005900  0.034623  0.000286
# 36130    -0.306812     0.419453    -0.600222 -0.025944  0.040966 -0.053644
# 36131    -0.306557     0.419467    -0.600259  0.008401 -0.000977  0.024358
# 36132    -0.306149     0.419332    -0.599809  0.013277 -0.002801 -0.038290
# 36133    -0.305498     0.419307    -0.599450  0.013655  0.018239 -0.064116
#
#           z_acc     y_acc     x_acc    bpm
# 265   -0.243557 -0.577762 -0.190925  105.0
# 266   -0.788626 -0.268524  0.834922  105.0
# 267   -0.398124 -0.406848  0.431240  105.0
# 268   -0.001588 -0.409412 -0.190077  105.0
# 269    0.145781 -0.103795 -0.076771  105.0
# ...         ...       ...       ...    ...
# 36129 -0.063131  0.121282  0.227220  137.0
# 36130  0.159545 -0.055427 -0.025500  137.0
# 36131  0.011866  0.086600  0.146586  137.0
# 36132  0.413557 -0.093723 -0.062594  137.0
# 36133  0.028775  0.028965 -0.067718  137.0
#
# [33919 rows x 21 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 153
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 merged_data[153]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 153

# %%
# 1:cycling 2:strength 3:Elyptic
filtered_df['sport']=1

# %% [markdown]
# We save it to a CSV

# %%
# Write the filtered DataFrame to a CSV file (change the name for each sport)
filtered_df.to_csv('clean_data_cycling.csv', index=False)
